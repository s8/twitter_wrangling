# %%
import json
import pandas as pd

# %%
with open('tweets_arrayed.txt', 'r') as json_file:
#     print(type(json_file).text)
#     contents = "[" + json_file.replace("}{", "},{") + "]"
    data = json.load(json_file)

# %%
tweets = pd.read_json ('tweets_arrayed.txt')

# %%
tweets.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           37242
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           32026
# ...

# %%
tweets.query("favorite_count > 100000")
# Out:
#      contributors  coordinates          created_at display_text_range  \
# 59            NaN          NaN 2017-06-26 19:07:24            [0, 82]
# 110           NaN          NaN 2017-05-22 00:28:40           [0, 106]
# 320           NaN          NaN 2017-01-21 18:26:02            [0, 87]
# 423           NaN          NaN 2016-12-09 06:17:20            [0, 61]
# 840           NaN          NaN 2016-06-18 18:26:18            [0, 91]
# 875           NaN          NaN 2016-06-04 23:31:25           [0, 114]
#
#                                               entities  \
# 59   {'hashtags': [], 'symbols': [], 'user_mentions...
# 110  {'hashtags': [], 'symbols': [], 'user_mentions...
# 320  {'hashtags': [{'text': 'WomensMarch', 'indices...
# 423  {'hashtags': [], 'symbols': [], 'user_mentions...
# 840  {'hashtags': [], 'symbols': [], 'user_mentions...
# 875  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                      extended_entities  favorite_count  \
# ...
