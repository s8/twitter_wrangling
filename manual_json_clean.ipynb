# %%
import json
import pandas as pd

# %%
with open('tweets_arrayed.txt', 'r') as json_file:
#     print(type(json_file).text)
#     contents = "[" + json_file.replace("}{", "},{") + "]"
    data = json.load(json_file)

# %%
tweets = pd.read_json ('tweets_arrayed.txt')

# %%
tweets.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           37242
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           32026
# ...

# %%
tweets.query("favorite_count > 100000")
# Out:
#      contributors  coordinates          created_at display_text_range  \
# 59            NaN          NaN 2017-06-26 19:07:24            [0, 82]
# 110           NaN          NaN 2017-05-22 00:28:40           [0, 106]
# 320           NaN          NaN 2017-01-21 18:26:02            [0, 87]
# 423           NaN          NaN 2016-12-09 06:17:20            [0, 61]
# 840           NaN          NaN 2016-06-18 18:26:18            [0, 91]
# 875           NaN          NaN 2016-06-04 23:31:25           [0, 114]
#
#                                               entities  \
# 59   {'hashtags': [], 'symbols': [], 'user_mentions...
# 110  {'hashtags': [], 'symbols': [], 'user_mentions...
# 320  {'hashtags': [{'text': 'WomensMarch', 'indices...
# 423  {'hashtags': [], 'symbols': [], 'user_mentions...
# 840  {'hashtags': [], 'symbols': [], 'user_mentions...
# 875  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                      extended_entities  favorite_count  \
# ...

# %%
# locate the single most popular tweet
tweets.iloc[840].entities['media'][0]['url']
# Out:
# 'https://t.co/7wE9LTEXC4'

# %%
# print out all original tweet URLs
for i, tweet in enumerate(tweets.iterrows()):
    print (tweets.iloc[i].entities['media'][0]['url'])
    hashtags = tweets.iloc[i].entities['hashtags']
    if len(hashtags) > 0:
        print (hashtags)
# Out:
# https://t.co/MgUWQ76dJU
# https://t.co/0Xxu71qeIV
# https://t.co/wUnZnhtVJB
# https://t.co/tD36da7qLQ
# https://t.co/AtUZn91f7f
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/kQ04fDDRmh
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/tVJBRMnhxl
# https://t.co/v0nONBcwxq
# https://t.co/9TwLuAGH0b
# [{'text': 'BarkWeek', 'indices': [113, 122]}]
# https://t.co/t1bfwz5S2A
# https://t.co/dVPW0B0Mme
# [{'text': 'BarkWeek', 'indices': [121, 130]}]
# https://t.co/u1XPQMl29g
# https://t.co/BxvuXk0UCm
# https://t.co/f8dEDcrKSR
# https://t.co/y70o6h3isq
# [{'text': 'BarkWeek', 'indices': [109, 118]}]
# https://t.co/WpHvrQedPb
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/chxruIOUJN
# https://t.co/HTQ77yNQ5K
# https://t.co/YnYAFCTTiK
# https://t.co/DK7iDPfuRX
# https://t.co/PhrUk20Q64
# https://t.co/20VrLAA8ba
# https://t.co/cLyzpcUcMX
# https://t.co/WZqNqygEyV
# https://t.co/4Ad1jzJSdp
# https://t.co/I6oNy0CgiT
# https://t.co/ISvKOSkd5b
# ...

# %%
hashtags = [{'text': 'LoveTwitter', 'indices': [61, 73]}]

print ('indices' in hashtags[0])
# Out:
# True

# %%
# print out all tweets with hashtags
for i, tweet in enumerate(tweets.iterrows()):
    hashtags = tweets.iloc[i].entities['hashtags']
    if len(hashtags) > 0:
        print (tweets.iloc[i].entities['media'][0]['url'])
        print (hashtags)
# Out:
# https://t.co/AtUZn91f7f
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/kQ04fDDRmh
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/9TwLuAGH0b
# [{'text': 'BarkWeek', 'indices': [113, 122]}]
# https://t.co/dVPW0B0Mme
# [{'text': 'BarkWeek', 'indices': [121, 130]}]
# https://t.co/y70o6h3isq
# [{'text': 'BarkWeek', 'indices': [109, 118]}]
# https://t.co/WpHvrQedPb
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/cgwJwowTMC
# [{'text': 'Canada150', 'indices': [111, 121]}]
# https://t.co/lNZwgNO4gS
# [{'text': 'PrideMonthPuppo', 'indices': [29, 45]}, {'text': 'PrideMonth', 'indices': [115, 126]}]
# https://t.co/XBE0evJZ6V
# [{'text': 'PrideMonth', 'indices': [122, 133]}]
# https://t.co/17FVMl4VZ5
# [{'text': 'dogsatpollingstations', 'indices': [21, 43]}]
# https://t.co/lUcpnZDPz9
# [{'text': 'PrideMonth', 'indices': [66, 77]}]
# https://t.co/uK6PNyeh9w
# [{'text': 'PrideMonth', 'indices': [39, 50]}]
# https://t.co/cMhq16isel
# ...

# %%
# print out all tweets with hashtags
for i, tweet in enumerate(tweets.iterrows()):
    hashtags = tweets.iloc[i].entities['hashtags']
    if len(hashtags) > 0:
        print (tweets.iloc[i].entities['media'][0]['url'])
        print (hashtags)
# Out:
# https://t.co/AtUZn91f7f
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/kQ04fDDRmh
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/9TwLuAGH0b
# [{'text': 'BarkWeek', 'indices': [113, 122]}]
# https://t.co/dVPW0B0Mme
# [{'text': 'BarkWeek', 'indices': [121, 130]}]
# https://t.co/y70o6h3isq
# [{'text': 'BarkWeek', 'indices': [109, 118]}]
# https://t.co/WpHvrQedPb
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/cgwJwowTMC
# [{'text': 'Canada150', 'indices': [111, 121]}]
# https://t.co/lNZwgNO4gS
# [{'text': 'PrideMonthPuppo', 'indices': [29, 45]}, {'text': 'PrideMonth', 'indices': [115, 126]}]
# https://t.co/XBE0evJZ6V
# [{'text': 'PrideMonth', 'indices': [122, 133]}]
# https://t.co/17FVMl4VZ5
# [{'text': 'dogsatpollingstations', 'indices': [21, 43]}]
# https://t.co/lUcpnZDPz9
# [{'text': 'PrideMonth', 'indices': [66, 77]}]
# https://t.co/uK6PNyeh9w
# [{'text': 'PrideMonth', 'indices': [39, 50]}]
# https://t.co/cMhq16isel
# ...

# %%
# print out all #BarkWeek tweets
for i, tweet in enumerate(tweets.iterrows()):
    hashtags = tweets.iloc[i].entities['hashtags']
    if len(hashtags) > 0:
        if (hashtags[0]['text']) == "BarkWeek":
            print (tweets.iloc[i].entities['media'][0]['url'])
            print (hashtags)
# Out:
# https://t.co/AtUZn91f7f
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/kQ04fDDRmh
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/9TwLuAGH0b
# [{'text': 'BarkWeek', 'indices': [113, 122]}]
# https://t.co/dVPW0B0Mme
# [{'text': 'BarkWeek', 'indices': [121, 130]}]
# https://t.co/y70o6h3isq
# [{'text': 'BarkWeek', 'indices': [109, 118]}]
# https://t.co/WpHvrQedPb
# [{'text': 'BarkWeek', 'indices': [129, 138]}]
# https://t.co/eA7k1ZQslA
# [{'text': 'BarkWeek', 'indices': [0, 9]}]
# https://t.co/V7h5NMYbYz
# [{'text': 'BarkWeek', 'indices': [32, 41]}]

# %%
print(tweets.iloc[840].entities['hashtags'])
# Out:
# []

# %%
tweets.iloc[840].entities
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [],
#  'media': [{'id': 744234667679821824,
#    'id_str': '744234667679821824',
#    'indices': [92, 115],
#    'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg',
#    'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg',
#    'url': 'https://t.co/7wE9LTEXC4',
#    'display_url': 'pic.twitter.com/7wE9LTEXC4',
#    'expanded_url': 'https://twitter.com/dog_rates/status/744234799360020481/video/1',
#    'type': 'photo',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#     'medium': {'w': 406, 'h': 720, 'resize': 'fit'},
#     'large': {'w': 406, 'h': 720, 'resize': 'fit'}}}]}

# %%
tweets.iloc[840].extended_entities
# Out:
# {'media': [{'id': 744234667679821824,
#    'id_str': '744234667679821824',
#    'indices': [92, 115],
#    'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg',
#    'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg',
#    'url': 'https://t.co/7wE9LTEXC4',
#    'display_url': 'pic.twitter.com/7wE9LTEXC4',
#    'expanded_url': 'https://twitter.com/dog_rates/status/744234799360020481/video/1',
#    'type': 'video',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#     'medium': {'w': 406, 'h': 720, 'resize': 'fit'},
#     'large': {'w': 406, 'h': 720, 'resize': 'fit'}},
#    'video_info': {'aspect_ratio': [203, 360],
#     'duration_millis': 30026,
#     'variants': [{'bitrate': 832000,
#       'content_type': 'video/mp4',
# ...

# %%
tweets.iloc[840].full_text
# Out:
# "Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4"

# %%
tweets.iloc[840].user
# Out:
# {'id': 4196983835,
#  'id_str': '4196983835',
#  'name': 'WeRateDogs™',
#  'screen_name': 'dog_rates',
#  'location': '「 DM YOUR DOGS 」',
#  'description': 'Your Only Source For Professional Dog Ratings Instagram and Facebook ➪ WeRateDogs partnerships@weratedogs.com ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀',
#  'url': 'https://t.co/N7sNNHSfPq',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/N7sNNHSfPq',
#      'expanded_url': 'http://weratedogs.com',
#      'display_url': 'weratedogs.com',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 8277001,
#  'friends_count': 12,
#  'listed_count': 6384,
#  'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#  'favourites_count': 142629,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 10628,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
# ...

# %%
# print (tweets.iloc[i].entities['media'][0]['url'])
print (tweets.iloc[840].entities['hashtags'])
# Out:
# []
